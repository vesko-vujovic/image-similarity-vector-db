# %%
# %pip install numpy
# %pip install tqdm
# %pip install torch
# %pip install torchvision
# %pip install qdrant_client
# %pip install fastapi
# %pip install uvicorn
# %pip install python-multipart
# %pip install streamlit
# %pip install streamlit-jupyter
# Out:
# Requirement already satisfied: numpy in /home/vesko/anaconda3/lib/python3.12/site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /home/vesko/anaconda3/lib/python3.12/site-packages (4.66.5)
# Note: you may need to restart the kernel to use updated packages.
# Collecting torch
#   Using cached torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: filelock in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: setuptools in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch) (75.1.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch)
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch)
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch)
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch)
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch)
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch)
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch)
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch)
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.0 (from torch)
#   Using cached triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Using cached torch-2.7.0-cp312-cp312-manylinux_2_28_x86_64.whl (865.0 MB)
# Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (156.5 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 sympy-1.14.0 torch-2.7.0 triton-3.3.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting torchvision
#   Using cached torchvision-0.22.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in /home/vesko/anaconda3/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.7.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torchvision) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: filelock in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (4.11.0)
# Requirement already satisfied: setuptools in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.7.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jinja2->torch==2.7.0->torchvision) (2.1.3)
# Using cached torchvision-0.22.0-cp312-cp312-manylinux_2_28_x86_64.whl (7.4 MB)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.22.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting qdrant_client
#   Using cached qdrant_client-1.14.2-py3-none-any.whl.metadata (10 kB)
# Collecting grpcio>=1.41.0 (from qdrant_client)
#   Using cached grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: httpx>=0.20.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx[http2]>=0.20.0->qdrant_client) (0.27.0)
# Requirement already satisfied: numpy>=1.26 in /home/vesko/anaconda3/lib/python3.12/site-packages (from qdrant_client) (1.26.4)
# Collecting portalocker<3.0.0,>=2.7.0 (from qdrant_client)
#   Using cached portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: protobuf>=3.20.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from qdrant_client) (4.25.3)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8 in /home/vesko/anaconda3/lib/python3.12/site-packages (from qdrant_client) (2.8.2)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /home/vesko/anaconda3/lib/python3.12/site-packages (from qdrant_client) (2.2.3)
# Requirement already satisfied: anyio in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (4.2.0)
# Requirement already satisfied: certifi in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (1.0.2)
# Requirement already satisfied: idna in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (3.7)
# Requirement already satisfied: sniffio in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant_client) (0.14.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.20.0->qdrant_client)
#   Using cached h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.0,>=1.10.8->qdrant_client) (4.11.0)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client)
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant_client)
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Using cached qdrant_client-1.14.2-py3-none-any.whl (327 kB)
# Using cached grpcio-1.71.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Using cached portalocker-2.10.1-py3-none-any.whl (18 kB)
# Using cached h2-4.2.0-py3-none-any.whl (60 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Installing collected packages: portalocker, hyperframe, hpack, grpcio, h2, qdrant_client
# Successfully installed grpcio-1.71.0 h2-4.2.0 hpack-4.1.0 hyperframe-6.1.0 portalocker-2.10.1 qdrant_client-1.14.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting fastapi
#   Using cached fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi)
#   Using cached starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from fastapi) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in /home/vesko/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.0)
# Using cached fastapi-0.115.12-py3-none-any.whl (95 kB)
# Using cached starlette-0.46.2-py3-none-any.whl (72 kB)
# Installing collected packages: starlette, fastapi
# Successfully installed fastapi-0.115.12 starlette-0.46.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting uvicorn
#   Using cached uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click>=7.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/vesko/anaconda3/lib/python3.12/site-packages (from uvicorn) (0.14.0)
# Using cached uvicorn-0.34.2-py3-none-any.whl (62 kB)
# Installing collected packages: uvicorn
# Successfully installed uvicorn-0.34.2
# Note: you may need to restart the kernel to use updated packages.
# Collecting python-multipart
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Installing collected packages: python-multipart
# Successfully installed python-multipart-0.0.20
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit in /home/vesko/anaconda3/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: jinja2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /home/vesko/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting streamlit-jupyter
#   Using cached streamlit_jupyter-0.2.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting fastcore (from streamlit-jupyter)
#   Using cached fastcore-1.8.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipywidgets==7.7.2 (from streamlit-jupyter)
#   Using cached ipywidgets-7.7.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jupyter in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit-jupyter) (1.0.0)
# Collecting stqdm (from streamlit-jupyter)
#   Using cached stqdm-0.0.5-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: streamlit>=1.19 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit-jupyter) (1.37.1)
# Requirement already satisfied: tabulate in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit-jupyter) (0.9.0)
# Requirement already satisfied: tqdm in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit-jupyter) (4.66.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (1.0.0)
# Requirement already satisfied: altair<6,>=4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (6.4.1)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (4.0.1)
# Requirement already satisfied: notebook in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (7.2.2)
# Requirement already satisfied: qtconsole in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (5.5.1)
# Requirement already satisfied: jupyter-console in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (7.16.4)
# Requirement already satisfied: jinja2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (4.23.0)
# Requirement already satisfied: toolz in /home/vesko/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (4.0.7)
# Requirement already satisfied: comm>=0.1.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.6.0)
# Requirement already satisfied: psutil in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (25.1.2)
# Requirement already satisfied: decorator in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.15.1)
# Requirement already satisfied: stack-data in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit-jupyter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit-jupyter) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit-jupyter) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vesko/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit>=1.19->streamlit-jupyter) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (1.2.1)
# Requirement already satisfied: qtpy>=2.4.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from qtconsole->jupyter->streamlit-jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->streamlit-jupyter) (1.16.0)
# Requirement already satisfied: webencodings in /home/vesko/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->streamlit-jupyter) (0.5.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (3.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->streamlit-jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->streamlit-jupyter) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->streamlit-jupyter) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook->jupyter->streamlit-jupyter) (75.1.0)
# Requirement already satisfied: babel>=2.10 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit-jupyter) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit-jupyter) (0.9.6)
# Requirement already satisfied: mdurl~=0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.19->streamlit-jupyter) (0.1.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/vesko/anaconda3/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->streamlit-jupyter) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/vesko/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.7.0)
# Requirement already satisfied: wcwidth in /home/vesko/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /home/vesko/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit-jupyter) (2.5)
# Requirement already satisfied: executing in /home/vesko/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.8.3)
# Requirement already satisfied: asttokens in /home/vesko/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in /home/vesko/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.2)
# Requirement already satisfied: sniffio>=1.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/vesko/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->streamlit-jupyter) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/vesko/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook->jupyter->streamlit-jupyter) (0.14.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.1.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Using cached fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Using cached isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /home/vesko/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Using cached uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Using cached webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/vesko/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/vesko/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/vesko/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.2.3)
# Using cached streamlit_jupyter-0.2.1-py3-none-any.whl (13 kB)
# Using cached ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Using cached fastcore-1.8.2-py3-none-any.whl (78 kB)
# Using cached stqdm-0.0.5-py3-none-any.whl (11 kB)
# Using cached webcolors-24.11.1-py3-none-any.whl (14 kB)
# Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Using cached uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, fqdn, fastcore, isoduration, stqdm, ipywidgets, streamlit-jupyter
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.8.1
#     Uninstalling ipywidgets-7.8.1:
#       Successfully uninstalled ipywidgets-7.8.1
# Successfully installed fastcore-1.8.2 fqdn-1.5.1 ipywidgets-7.7.2 isoduration-20.11.0 stqdm-0.0.5 streamlit-jupyter-0.2.1 uri-template-1.3.0 webcolors-24.11.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Listing all images

# %%
import os
from pathlib import Path

# Define image directory
image_dir = Path("./data/images/")

# Get all image paths
image_paths = [str(f) for f in image_dir.glob("*.jpg")]
print(f"Found {len(image_paths)} images")
# Out:
# Found 17 images

# %% [markdown]
# # Generating Vector Embeddings

# %%
import numpy as np
from tqdm import tqdm
import torch
from torchvision import models, transforms
from PIL import Image

model = models.resnet50(pretrained=True)

# Remove the classification layer to get embeddings
model = torch.nn.Sequential(*(list(model.children())[:-1]))
model.eval()

# Prepare image transformation
transform = transforms.Compose([
    transforms.Resize(1024),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], 
                         std=[0.229, 0.224, 0.225])
])

def get_image_embedding(image_path):
    # Load and transform image
    img = Image.open(image_path).convert('RGB')
    img_t = transform(img)
    batch_t = torch.unsqueeze(img_t, 0)
    
    # Get embedding
    with torch.no_grad():
        embedding = model(batch_t)
    
    # Flatten to 1D vector and return as numpy array
    return embedding.squeeze().cpu().numpy()




# Generate embeddings for all images
embeddings = {}
for img_path in tqdm(image_paths, desc="Generating embeddings"):
    try:
        # Get the image ID from the filename
        img_id = os.path.basename(img_path).split('.')[0]
        # Generate embedding
        embedding = get_image_embedding(img_path)
        embeddings[img_id] = embedding
    except Exception as e:
        print(f"Error processing {img_path}: {e}")

print(f"Generated embeddings for {len(embeddings)} images")
# Out:
# Generating embeddings: 100%|██████████| 17/17 [00:03<00:00,  4.48it/s]
# Generated embeddings for 17 images

# %% [markdown]
# # Storing Vectors in a Vector Database

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, Distance, PointStruct

# Initialize Qdrant client - local one
collection_name = "fruits_and_vegetables"

client = ""

if not client:
    client = QdrantClient(path="./qdrant_data")

# Create a new collection for our image embeddings
vector_size = next(iter(embeddings.values())).shape[0]  # Get dimension from first embedding


client.recreate_collection(
    collection_name=collection_name,
    vectors_config=VectorParams(size=vector_size, distance=Distance.COSINE)
)

# Prepare points for upload
cnt = 1
embedded_images = []
for img_id, embedding in embeddings.items():
    cnt+=1
    embedded_images.append(PointStruct(
        id=cnt,
        vector=embedding.tolist(),
        payload={"image_path": str(image_dir / f"{img_id}.jpg"), "name": img_id}
    ))

# Upload in batches
batch_size = 10

for i in range(0, len(embedded_images), batch_size):
    client.upsert(
        collection_name=collection_name,
        points=embedded_images[i:i + batch_size]
    )

print(f"Uploaded {len(embedded_images)} embeddings to Qdrant")
# Out:
# /tmp/ipykernel_12502/886451275.py:16: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(
# Uploaded 17 embeddings to Qdrant

# %% [markdown]
# # Creating the Search API

# %%
import nest_asyncio
import uvicorn
import threading
from fastapi import FastAPI, UploadFile, File
from fastapi.middleware.cors import CORSMiddleware
import os
import tempfile

print(client)

# Apply nest_asyncio to allow running asyncio event loops within Jupyter
nest_asyncio.apply()

# Create the FastAPI app
app = FastAPI()

# Add CORS middleware to allow requests from the Jupyter environment
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

@app.post("/search")
async def search_similar(
    file: UploadFile = File(...),
    limit: int = 5
):
    # Save uploaded file temporarily
    with tempfile.NamedTemporaryFile(delete=False, suffix=".jpg") as temp:
        temp.write(await file.read())
        temp_path = temp.name
    
    try:
        # Generate embedding for uploaded image
        query_embedding = get_image_embedding(temp_path)
        
        # Search for similar images
        search_results = client.search(
            collection_name="fruits_and_vegetables",
            query_vector=query_embedding.tolist(),
            limit=limit
        )
        
        # Format results
        results = []
        for res in search_results:
            results.append({
                "image_id": res.id,
                "image_path": res.payload["image_path"],
                "similarity": res.score
            })
        
        return {"results": results[:2]}
    finally:
        # Clean up
        os.unlink(temp_path)

# Function to start the FastAPI server in a separate thread
def run_fastapi(host="127.0.0.1", port=8000):
    server = uvicorn.Server(config=uvicorn.Config(app=app, host=host, port=port))
    thread = threading.Thread(target=server.run)
    thread.daemon = True
    thread.start()
    print(f"FastAPI running on http://{host}:{port}")
    return thread

# Start the server
fastapi_thread = run_fastapi()

# Display URL for testing
from IPython.display import display, HTML
display(HTML('<a href="http://127.0.0.1:8000/docs" target="_blank">Open FastAPI Swagger UI</a>'))
# Out:
# <qdrant_client.qdrant_client.QdrantClient object at 0x7f25d0384740>
# FastAPI running on http://127.0.0.1:8000
# <a href="http://127.0.0.1:8000/docs" target="_blank">Open FastAPI Swagger UI</a>

# %% [markdown]
# # Building a Simple UI for Image Search
